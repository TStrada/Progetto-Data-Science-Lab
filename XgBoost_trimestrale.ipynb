# %% [markdown]
# #**Osservazioni sulle vendite trimestrali di prodotti dei settori Calcio, Pesca e Casual**

# %%
#https://github.com/TommasoStrada/Progetto-Data-Science-Lab

# %% [markdown]
# The XGBoost (eXtreme Gradient Boosting) is a popular and efficient open-source implementation of the gradient boosted trees algorithm. Gradient boosting is a supervised learning algorithm that attempts to accurately predict a target variable by combining an ensemble of estimates from a set of simpler and weaker models. The XGBoost algorithm performs well in machine learning competitions because of its robust handling of a variety of data types, relationships, distributions, and the variety of hyperparameters that you can fine-tune. You can use XGBoost for regression, classification (binary and multiclass), and ranking problems.

# %%
#!pip install xgboost 1.6

# %%
import math
import pandas as pd
import seaborn as sns
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.model_selection import train_test_split
from xgboost import XGBRegressor
import xgboost

# %%
shift_trimestre = 1     #trimestre precedente
shift_annuale = 4       #stesso trimestre, anno precedente
shift_scelto = shift_trimestre

# %%
repo_alessandro_calcio = "https://github.com/Alessandro-Fasani/DsLab/raw/main/calcio_trimestrale.csv"
repo_alessandro_pesca = "https://github.com/Alessandro-Fasani/DsLab/raw/main/pesca_trimestrale.csv"
repo_alessandro_casual = "https://github.com/Alessandro-Fasani/DsLab/raw/main/casual_trimestrale.csv"

repo_team_calcio = ""
repo_team_pesca = ""
repo_team_casual = ""

# %%
ds_calcio = pd.read_csv(repo_alessandro_calcio)
ds_pesca = pd.read_csv(repo_alessandro_pesca)
ds_casual = pd.read_csv(repo_alessandro_casual)

# %%
porzione_test = round(len(ds_calcio) * 0.2)       # 20% circa verra usato per il test  

ds_casual.head(50)
# Out:
#     Unnamed: 0        year     revenue
# 0            0  2014-03-31   618890.53
# 1            1  2014-06-30   886224.60
# 2            2  2014-09-30  1133497.77
# 3            3  2014-12-31   877819.29
# 4            4  2015-03-31  1661470.04
# 5            5  2015-06-30  1461337.48
# 6            6  2015-09-30  1415946.31
# 7            7  2015-12-31  1277021.07
# 8            8  2016-03-31  1307658.25
# 9            9  2016-06-30  1307577.72
# 10          10  2016-09-30  1430940.22
# 11          11  2016-12-31  1299168.05
# 12          12  2017-03-31  1439017.27
# 13          13  2017-06-30  1121432.36
# 14          14  2017-09-30  1509452.17
# 15          15  2017-12-31  1468547.48
# 16          16  2018-03-31  1378093.47
# 17          17  2018-06-30  1098375.27
# 18          18  2018-09-30  1291459.70
# 19          19  2018-12-31   976010.81
# 20          20  2019-03-31  1346662.49
# 21          21  2019-06-30   365637.18
# 22          22  2019-09-30  1020065.25
# 23          23  2019-12-31   464887.92
# 24          24  2020-03-31   628588.60
# 25          25  2020-06-30  1731979.27
# 26          26  2020-09-30   674152.55
# 27          27  2020-12-31   789520.75
# 28          28  2021-03-31   985770.75
# 29          29  2021-06-30   709238.48
# 30          30  2021-09-30   543018.66
# 31          31  2021-12-31   664677.44
# 32          32  2022-03-31   535933.31

# %%
ds_calcio['year'] = pd.to_datetime(ds_calcio['year'])
ds_pesca['year'] = pd.to_datetime(ds_pesca['year'])
ds_casual['year'] = pd.to_datetime(ds_casual['year'])
ds_calcio.dtypes
# Out:
# Unnamed: 0             int64
# year          datetime64[ns]
# revenue              float64
# dtype: object

# %%
print("xgboost versione numero: ", xgboost.__version__)
# Out:
# xgboost versione numero:  0.90

# %%
plt.rcParams.update({'figure.figsize': (17, 5), 'figure.dpi':300})
fig, ax = plt.subplots()
sns.lineplot(data=ds_calcio, x='year',  y='revenue')
plt.grid(linestyle='-', linewidth=0.3)
plt.title("Totale vendite Calcio per trimestre")
ax.tick_params(axis='x', rotation=90)

# %%
plt.rcParams.update({'figure.figsize': (17, 5), 'figure.dpi':300})
fig, ax = plt.subplots()
sns.lineplot(data=ds_pesca, x='year',  y='revenue')
plt.grid(linestyle='-', linewidth=0.3)
plt.title("Totale vendite Pesca per trimestre")
ax.tick_params(axis='x', rotation=90)

# %%
plt.rcParams.update({'figure.figsize': (17, 5), 'figure.dpi':300})
fig, ax = plt.subplots()
sns.lineplot(data=ds_casual, x='year',  y='revenue')
plt.title("Totale vendite Pesca per trimestre")
plt.grid(linestyle='-', linewidth=0.3)
ax.tick_params(axis='x', rotation=90)

# %%
ds_calcio["totale_periodo_prec"] = ds_calcio["revenue"].shift(+shift_scelto)
ds_pesca["totale_periodo_prec"] = ds_pesca["revenue"].shift(+shift_scelto)
ds_casual["totale_periodo_prec"] = ds_casual["revenue"].shift(+shift_scelto)


ds_calcio= ds_calcio.dropna()  
ds_pesca= ds_pesca.dropna()    
ds_casual= ds_casual.dropna()


print(ds_calcio.shape)
print(ds_pesca.shape)
print(ds_casual.shape)
# Out:
# (32, 4)
# (32, 4)
# (32, 4)

# %%
#LIST INPUT, divisione tra parte train e parte dedicata al test
x_calcio = ds_calcio[['totale_periodo_prec']]
x_pesca = ds_pesca[['totale_periodo_prec']]
x_casual = ds_casual[['totale_periodo_prec']]

x_calcio_to_train = x_calcio.iloc[:(len(x_calcio)-porzione_test)]
x_pesca_to_train = x_pesca.iloc[:(len(x_pesca)-porzione_test)]
x_casual_to_train = x_casual.iloc[:(len(x_casual)-porzione_test)]


x_calcio_to_test = x_calcio.iloc[(len(x_calcio)-porzione_test):]
x_pesca_to_test = x_pesca.iloc[(len(x_pesca)-porzione_test):]
x_casual_to_test = x_casual.iloc[(len(x_casual)-porzione_test):]


#LIST OUTPUT, divisione tra parte train e parte dedicata al test
y_calcio = ds_calcio[['revenue']]
y_pesca = ds_pesca[['revenue']]
y_casual = ds_casual[['revenue']]

y_calcio_to_train = y_calcio.iloc[:(len(y_calcio)-porzione_test)]
y_pesca_to_train = y_pesca.iloc[:(len(y_pesca)-porzione_test)]
y_casual_to_train = y_casual.iloc[:(len(y_casual)-porzione_test)]


y_calcio_to_test = y_calcio.iloc[(len(y_calcio)-porzione_test):]
y_pesca_to_test = y_pesca.iloc[(len(y_pesca)-porzione_test):]
y_casual_to_test = y_casual.iloc[(len(y_casual)-porzione_test):]


fig, ax = plt.subplots(figsize=(17, 3))
ax.plot(y_calcio_to_train, ls='-', label='Train')
ax.plot(y_calcio_to_test, ls='--', label='Test')
ax.set_xlabel('data')
ax.set_ylabel('Vendite')

ax.legend(loc='best')
plt.tight_layout()
plt.show()

# %%
estimator_calcio = XGBRegressor(objective='reg:squarederror', n_estimators=170, learning_rate=0.01)
estimator_pesca = XGBRegressor(objective='reg:squarederror', n_estimators=170, learning_rate=0.01)
estimator_casual = XGBRegressor(objective='reg:squarederror', n_estimators=170, learning_rate=0.01)

estimator_calcio.fit(x_calcio_to_train, y_calcio_to_train,
              eval_set=[(x_calcio_to_train, y_calcio_to_train), (x_calcio_to_test, y_calcio_to_test)],
              eval_metric='mae')

estimator_pesca.fit(x_pesca_to_train, y_pesca_to_train,
              eval_set=[(x_pesca_to_train, y_pesca_to_train), (x_pesca_to_test, y_pesca_to_test)],
              eval_metric='mae')

estimator_casual.fit(x_casual_to_train, y_casual_to_train,
              eval_set=[(x_casual_to_train, y_casual_to_train), (x_casual_to_test, y_casual_to_test)],
              eval_metric='mae')
# Out:
# [0]	validation_0-mae:1.22048e+06	validation_1-mae:1.12077e+06
# [1]	validation_0-mae:1.21004e+06	validation_1-mae:1.11096e+06
# [2]	validation_0-mae:1.19969e+06	validation_1-mae:1.10125e+06
# [3]	validation_0-mae:1.18944e+06	validation_1-mae:1.09161e+06
# [4]	validation_0-mae:1.17928e+06	validation_1-mae:1.08207e+06
# [5]	validation_0-mae:1.1692e+06	validation_1-mae:1.07261e+06
# [6]	validation_0-mae:1.15922e+06	validation_1-mae:1.06323e+06
# [7]	validation_0-mae:1.14933e+06	validation_1-mae:1.05394e+06
# [8]	validation_0-mae:1.13952e+06	validation_1-mae:1.04472e+06
# [9]	validation_0-mae:1.1298e+06	validation_1-mae:1.03559e+06
# [10]	validation_0-mae:1.12016e+06	validation_1-mae:1.02655e+06
# [11]	validation_0-mae:1.11061e+06	validation_1-mae:1.01758e+06
# [12]	validation_0-mae:1.10115e+06	validation_1-mae:1.00869e+06
# [13]	validation_0-mae:1.09177e+06	validation_1-mae:999878
# [14]	validation_0-mae:1.08247e+06	validation_1-mae:991146
# [15]	validation_0-mae:1.07326e+06	validation_1-mae:982492
# [16]	validation_0-mae:1.06412e+06	validation_1-mae:973914
# [17]	validation_0-mae:1.05507e+06	validation_1-mae:965413
# [18]	validation_0-mae:1.04609e+06	validation_1-mae:956986
# [19]	validation_0-mae:1.0372e+06	validation_1-mae:948635
# [20]	validation_0-mae:1.02839e+06	validation_1-mae:940357
# [21]	validation_0-mae:1.01965e+06	validation_1-mae:932153
# [22]	validation_0-mae:1.01121e+06	validation_1-mae:923294
# [23]	validation_0-mae:1.00284e+06	validation_1-mae:914507
# [24]	validation_0-mae:994542	validation_1-mae:905792
# [25]	validation_0-mae:986319	validation_1-mae:897148
# [26]	validation_0-mae:978166	validation_1-mae:888574
# [27]	validation_0-mae:970084	validation_1-mae:880070
# [28]	validation_0-mae:962073	validation_1-mae:871636
# [29]	validation_0-mae:954130	validation_1-mae:863270
# [30]	validation_0-mae:946257	validation_1-mae:854972
# [31]	validation_0-mae:938452	validation_1-mae:846742
# [32]	validation_0-mae:930714	validation_1-mae:838579
# [33]	validation_0-mae:923043	validation_1-mae:830482
# [34]	validation_0-mae:915439	validation_1-mae:822451
# [35]	validation_0-mae:907900	validation_1-mae:814486
# [36]	validation_0-mae:900426	validation_1-mae:806585
# [37]	validation_0-mae:893018	validation_1-mae:798748
# [38]	validation_0-mae:885673	validation_1-mae:790975
# [39]	validation_0-mae:878391	validation_1-mae:783265
# [40]	validation_0-mae:871173	validation_1-mae:775618
# [41]	validation_0-mae:864016	validation_1-mae:768032
# [42]	validation_0-mae:856922	validation_1-mae:760509
# [43]	validation_0-mae:849889	validation_1-mae:753046
# [44]	validation_0-mae:842916	validation_1-mae:745644
# [45]	validation_0-mae:836237	validation_1-mae:737940
# [46]	validation_0-mae:829613	validation_1-mae:730298
# [47]	validation_0-mae:823044	validation_1-mae:722717
# [48]	validation_0-mae:816530	validation_1-mae:715198
# [49]	validation_0-mae:809844	validation_1-mae:708085
# [50]	validation_0-mae:803365	validation_1-mae:700997
# [51]	validation_0-mae:797013	validation_1-mae:693645
# [52]	validation_0-mae:790641	validation_1-mae:686668
# [53]	validation_0-mae:784393	validation_1-mae:679425
# [54]	validation_0-mae:777983	validation_1-mae:672570
# [55]	validation_0-mae:771768	validation_1-mae:665750
# [56]	validation_0-mae:765675	validation_1-mae:658667
# [57]	validation_0-mae:759562	validation_1-mae:651954
# [58]	validation_0-mae:753571	validation_1-mae:644976
# [59]	validation_0-mae:747629	validation_1-mae:638053
# [60]	validation_0-mae:741463	validation_1-mae:631805
# [61]	validation_0-mae:735619	validation_1-mae:624980
# [62]	validation_0-mae:729755	validation_1-mae:618520
# [63]	validation_0-mae:724008	validation_1-mae:611796
# [64]	validation_0-mae:718309	validation_1-mae:605125
# [65]	validation_0-mae:712394	validation_1-mae:599109
# [66]	validation_0-mae:706790	validation_1-mae:592533
# [67]	validation_0-mae:701162	validation_1-mae:587128
# [68]	validation_0-mae:695651	validation_1-mae:583700
# [69]	validation_0-mae:690184	validation_1-mae:581014
# [70]	validation_0-mae:684510	validation_1-mae:578593
# [71]	validation_0-mae:679135	validation_1-mae:575947
# [72]	validation_0-mae:673735	validation_1-mae:573423
# [73]	validation_0-mae:668448	validation_1-mae:570818
# [74]	validation_0-mae:663205	validation_1-mae:568234
# [75]	validation_0-mae:658131	validation_1-mae:566003
# [76]	validation_0-mae:652971	validation_1-mae:563456
# [77]	validation_0-mae:647978	validation_1-mae:561258
# [78]	validation_0-mae:642900	validation_1-mae:558746
# [79]	validation_0-mae:638053	validation_1-mae:556482
# [80]	validation_0-mae:633178	validation_1-mae:554332
# [81]	validation_0-mae:628219	validation_1-mae:551873
# [82]	validation_0-mae:623422	validation_1-mae:549754
# [83]	validation_0-mae:618728	validation_1-mae:547552
# [84]	validation_0-mae:613886	validation_1-mae:545144
# [85]	validation_0-mae:609202	validation_1-mae:543071
# [86]	validation_0-mae:604620	validation_1-mae:540915
# [87]	validation_0-mae:599825	validation_1-mae:538654
# [88]	validation_0-mae:595318	validation_1-mae:536528
# [89]	validation_0-mae:590845	validation_1-mae:534418
# [90]	validation_0-mae:586161	validation_1-mae:532204
# [91]	validation_0-mae:581761	validation_1-mae:530124
# [92]	validation_0-mae:577433	validation_1-mae:527942
# [93]	validation_0-mae:573552	validation_1-mae:525891
# [94]	validation_0-mae:569737	validation_1-mae:523854
# [95]	validation_0-mae:565598	validation_1-mae:521718
# [96]	validation_0-mae:561842	validation_1-mae:519710
# [97]	validation_0-mae:558050	validation_1-mae:517810
# [98]	validation_0-mae:554067	validation_1-mae:515625
# [99]	validation_0-mae:550334	validation_1-mae:513753
# [100]	validation_0-mae:546412	validation_1-mae:511598
# [101]	validation_0-mae:542800	validation_1-mae:509659
# [102]	validation_0-mae:539151	validation_1-mae:507827
# [103]	validation_0-mae:535502	validation_1-mae:505716
# [104]	validation_0-mae:532219	validation_1-mae:503911
# [105]	validation_0-mae:529024	validation_1-mae:502025
# [106]	validation_0-mae:525526	validation_1-mae:499957
# [107]	validation_0-mae:522316	validation_1-mae:498190
# [108]	validation_0-mae:518869	validation_1-mae:496151
# [109]	validation_0-mae:515707	validation_1-mae:494410
# [110]	validation_0-mae:512632	validation_1-mae:492589
# [111]	validation_0-mae:509196	validation_1-mae:490683
# [112]	validation_0-mae:506167	validation_1-mae:488887
# [113]	validation_0-mae:503161	validation_1-mae:487104
# [114]	validation_0-mae:499986	validation_1-mae:485236
# [115]	validation_0-mae:497130	validation_1-mae:483478
# [116]	validation_0-mae:494125	validation_1-mae:481638
# [117]	validation_0-mae:491311	validation_1-mae:479904
# [118]	validation_0-mae:488517	validation_1-mae:478182
# [119]	validation_0-mae:485575	validation_1-mae:476379
# [120]	validation_0-mae:482821	validation_1-mae:474682
# [121]	validation_0-mae:480028	validation_1-mae:473084
# [122]	validation_0-mae:477207	validation_1-mae:471229
# [123]	validation_0-mae:474454	validation_1-mae:469655
# [124]	validation_0-mae:471673	validation_1-mae:467825
# [125]	validation_0-mae:469018	validation_1-mae:466186
# [126]	validation_0-mae:466324	validation_1-mae:464645
# [127]	validation_0-mae:463600	validation_1-mae:462852
# [128]	validation_0-mae:460944	validation_1-mae:461333
# [129]	validation_0-mae:458337	validation_1-mae:459430
# [130]	validation_0-mae:455718	validation_1-mae:457934
# [131]	validation_0-mae:453146	validation_1-mae:456054
# [132]	validation_0-mae:450702	validation_1-mae:454398
# [133]	validation_0-mae:448149	validation_1-mae:452629
# [134]	validation_0-mae:445826	validation_1-mae:450994
# [135]	validation_0-mae:443634	validation_1-mae:449249
# [136]	validation_0-mae:441265	validation_1-mae:447730
# [137]	validation_0-mae:439027	validation_1-mae:446382
# [138]	validation_0-mae:436767	validation_1-mae:444788
# [139]	validation_0-mae:434446	validation_1-mae:443297
# [140]	validation_0-mae:432329	validation_1-mae:441605
# [141]	validation_0-mae:430115	validation_1-mae:440043
# [142]	validation_0-mae:427952	validation_1-mae:438742
# [143]	validation_0-mae:425800	validation_1-mae:437198
# [144]	validation_0-mae:423999	validation_1-mae:435840
# [145]	validation_0-mae:422068	validation_1-mae:434314
# [146]	validation_0-mae:419765	validation_1-mae:432964
# [147]	validation_0-mae:418077	validation_1-mae:431541
# [148]	validation_0-mae:416110	validation_1-mae:430133
# [149]	validation_0-mae:414136	validation_1-mae:428532
# [150]	validation_0-mae:412490	validation_1-mae:427054
# [151]	validation_0-mae:410717	validation_1-mae:425833
# [152]	validation_0-mae:409391	validation_1-mae:424461
# [153]	validation_0-mae:408147	validation_1-mae:423009
# [154]	validation_0-mae:406418	validation_1-mae:421457
# [155]	validation_0-mae:405192	validation_1-mae:420025
# [156]	validation_0-mae:403523	validation_1-mae:418846
# [157]	validation_0-mae:402241	validation_1-mae:417517
# [158]	validation_0-mae:400873	validation_1-mae:416192
# [159]	validation_0-mae:399398	validation_1-mae:414955
# [160]	validation_0-mae:398047	validation_1-mae:413646
# [161]	validation_0-mae:396799	validation_1-mae:412348
# [162]	validation_0-mae:395309	validation_1-mae:410790
# [163]	validation_0-mae:393983	validation_1-mae:409506
# [164]	validation_0-mae:392606	validation_1-mae:408310
# [165]	validation_0-mae:391273	validation_1-mae:407127
# [166]	validation_0-mae:390203	validation_1-mae:405787
# [167]	validation_0-mae:388763	validation_1-mae:404354
# [168]	validation_0-mae:387616	validation_1-mae:403114
# [169]	validation_0-mae:386211	validation_1-mae:402038
# [0]	validation_0-mae:1.66851e+06	validation_1-mae:1.77619e+06
# [1]	validation_0-mae:1.65297e+06	validation_1-mae:1.7573e+06
# [2]	validation_0-mae:1.63753e+06	validation_1-mae:1.73889e+06
# [3]	validation_0-mae:1.62228e+06	validation_1-mae:1.72035e+06
# [4]	validation_0-mae:1.60717e+06	validation_1-mae:1.70199e+06
# [5]	validation_0-mae:1.59207e+06	validation_1-mae:1.68409e+06
# [6]	validation_0-mae:1.57724e+06	validation_1-mae:1.66607e+06
# [7]	validation_0-mae:1.56241e+06	validation_1-mae:1.64851e+06
# [8]	validation_0-mae:1.54786e+06	validation_1-mae:1.63083e+06
# [9]	validation_0-mae:1.53345e+06	validation_1-mae:1.61332e+06
# [10]	validation_0-mae:1.51903e+06	validation_1-mae:1.59625e+06
# [11]	validation_0-mae:1.50489e+06	validation_1-mae:1.57906e+06
# [12]	validation_0-mae:1.49087e+06	validation_1-mae:1.56204e+06
# [13]	validation_0-mae:1.47686e+06	validation_1-mae:1.54545e+06
# [14]	validation_0-mae:1.46311e+06	validation_1-mae:1.52874e+06
# [15]	validation_0-mae:1.44936e+06	validation_1-mae:1.51246e+06
# [16]	validation_0-mae:1.43586e+06	validation_1-mae:1.49607e+06
# [17]	validation_0-mae:1.42248e+06	validation_1-mae:1.47983e+06
# [18]	validation_0-mae:1.40912e+06	validation_1-mae:1.46401e+06
# [19]	validation_0-mae:1.39583e+06	validation_1-mae:1.44858e+06
# [20]	validation_0-mae:1.38283e+06	validation_1-mae:1.4328e+06
# [21]	validation_0-mae:1.36995e+06	validation_1-mae:1.41716e+06
# [22]	validation_0-mae:1.35704e+06	validation_1-mae:1.40216e+06
# [23]	validation_0-mae:1.3444e+06	validation_1-mae:1.38682e+06
# [24]	validation_0-mae:1.33188e+06	validation_1-mae:1.37162e+06
# [25]	validation_0-mae:1.31932e+06	validation_1-mae:1.35704e+06
# [26]	validation_0-mae:1.30703e+06	validation_1-mae:1.34212e+06
# [27]	validation_0-mae:1.29471e+06	validation_1-mae:1.32781e+06
# [28]	validation_0-mae:1.28265e+06	validation_1-mae:1.31317e+06
# [29]	validation_0-mae:1.27071e+06	validation_1-mae:1.29867e+06
# [30]	validation_0-mae:1.25873e+06	validation_1-mae:1.28476e+06
# [31]	validation_0-mae:1.24701e+06	validation_1-mae:1.27052e+06
# [32]	validation_0-mae:1.23539e+06	validation_1-mae:1.25642e+06
# [33]	validation_0-mae:1.22375e+06	validation_1-mae:1.2429e+06
# [34]	validation_0-mae:1.21235e+06	validation_1-mae:1.22906e+06
# [35]	validation_0-mae:1.20106e+06	validation_1-mae:1.21536e+06
# [36]	validation_0-mae:1.1901e+06	validation_1-mae:1.20112e+06
# [37]	validation_0-mae:1.17924e+06	validation_1-mae:1.18703e+06
# [38]	validation_0-mae:1.16849e+06	validation_1-mae:1.17306e+06
# [39]	validation_0-mae:1.15747e+06	validation_1-mae:1.16027e+06
# [40]	validation_0-mae:1.14669e+06	validation_1-mae:1.14719e+06
# [41]	validation_0-mae:1.13623e+06	validation_1-mae:1.1336e+06
# [42]	validation_0-mae:1.12586e+06	validation_1-mae:1.12013e+06
# [43]	validation_0-mae:1.11559e+06	validation_1-mae:1.10679e+06
# [44]	validation_0-mae:1.10517e+06	validation_1-mae:1.09439e+06
# [45]	validation_0-mae:1.09509e+06	validation_1-mae:1.08129e+06
# [46]	validation_0-mae:1.0851e+06	validation_1-mae:1.06832e+06
# [47]	validation_0-mae:1.0752e+06	validation_1-mae:1.05546e+06
# [48]	validation_0-mae:1.06539e+06	validation_1-mae:1.04273e+06
# [49]	validation_0-mae:1.05567e+06	validation_1-mae:1.03012e+06
# [50]	validation_0-mae:1.04604e+06	validation_1-mae:1.01762e+06
# [51]	validation_0-mae:1.03618e+06	validation_1-mae:1.00619e+06
# [52]	validation_0-mae:1.02653e+06	validation_1-mae:994481
# [53]	validation_0-mae:1.01714e+06	validation_1-mae:982320
# [54]	validation_0-mae:1.00783e+06	validation_1-mae:970274
# [55]	validation_0-mae:998609	validation_1-mae:958340
# [56]	validation_0-mae:989472	validation_1-mae:946519
# [57]	validation_0-mae:980419	validation_1-mae:934808
# [58]	validation_0-mae:971449	validation_1-mae:923207
# [59]	validation_0-mae:962375	validation_1-mae:912414
# [60]	validation_0-mae:953570	validation_1-mae:901023
# [61]	validation_0-mae:944845	validation_1-mae:889738
# [62]	validation_0-mae:936201	validation_1-mae:878560
# [63]	validation_0-mae:927636	validation_1-mae:867486
# [64]	validation_0-mae:919149	validation_1-mae:856516
# [65]	validation_0-mae:910588	validation_1-mae:846143
# [66]	validation_0-mae:902257	validation_1-mae:835373
# [67]	validation_0-mae:894003	validation_1-mae:824704
# [68]	validation_0-mae:885824	validation_1-mae:814135
# [69]	validation_0-mae:877721	validation_1-mae:803666
# [70]	validation_0-mae:869447	validation_1-mae:794075
# [71]	validation_0-mae:861493	validation_1-mae:783793
# [72]	validation_0-mae:853612	validation_1-mae:773608
# [73]	validation_0-mae:845803	validation_1-mae:763518
# [74]	validation_0-mae:837925	validation_1-mae:753977
# [75]	validation_0-mae:830259	validation_1-mae:744071
# [76]	validation_0-mae:822664	validation_1-mae:734258
# [77]	validation_0-mae:815138	validation_1-mae:724537
# [78]	validation_0-mae:807681	validation_1-mae:714907
# [79]	validation_0-mae:800293	validation_1-mae:705368
# [80]	validation_0-mae:792972	validation_1-mae:695918
# [81]	validation_0-mae:785719	validation_1-mae:686556
# [82]	validation_0-mae:778532	validation_1-mae:677282
# [83]	validation_0-mae:771235	validation_1-mae:668781
# [84]	validation_0-mae:764051	validation_1-mae:660085
# [85]	validation_0-mae:757062	validation_1-mae:651060
# [86]	validation_0-mae:750137	validation_1-mae:642119
# [87]	validation_0-mae:743275	validation_1-mae:633262
# [88]	validation_0-mae:736476	validation_1-mae:624488
# [89]	validation_0-mae:729740	validation_1-mae:615796
# [90]	validation_0-mae:723065	validation_1-mae:607185
# [91]	validation_0-mae:716451	validation_1-mae:598656
# [92]	validation_0-mae:709759	validation_1-mae:590709
# [93]	validation_0-mae:703267	validation_1-mae:582334
# [94]	validation_0-mae:696834	validation_1-mae:574037
# [95]	validation_0-mae:690461	validation_1-mae:565818
# [96]	validation_0-mae:684146	validation_1-mae:557676
# [97]	validation_0-mae:677888	validation_1-mae:549611
# [98]	validation_0-mae:671688	validation_1-mae:541621
# [99]	validation_0-mae:665546	validation_1-mae:533706
# [100]	validation_0-mae:659308	validation_1-mae:526445
# [101]	validation_0-mae:653166	validation_1-mae:519018
# [102]	validation_0-mae:647192	validation_1-mae:511315
# [103]	validation_0-mae:641273	validation_1-mae:503684
# [104]	validation_0-mae:635408	validation_1-mae:496125
# [105]	validation_0-mae:629597	validation_1-mae:488636
# [106]	validation_0-mae:623839	validation_1-mae:481218
# [107]	validation_0-mae:618011	validation_1-mae:474304
# [108]	validation_0-mae:612359	validation_1-mae:467021
# [109]	validation_0-mae:606759	validation_1-mae:459805
# [110]	validation_0-mae:601210	validation_1-mae:452657
# [111]	validation_0-mae:595609	validation_1-mae:445889
# [112]	validation_0-mae:590162	validation_1-mae:438872
# [113]	validation_0-mae:584765	validation_1-mae:431920
# [114]	validation_0-mae:579417	validation_1-mae:425034
# [115]	validation_0-mae:574118	validation_1-mae:418212
# [116]	validation_0-mae:568868	validation_1-mae:411454
# [117]	validation_0-mae:563666	validation_1-mae:404759
# [118]	validation_0-mae:558512	validation_1-mae:398127
# [119]	validation_0-mae:553405	validation_1-mae:391557
# [120]	validation_0-mae:548344	validation_1-mae:385049
# [121]	validation_0-mae:543330	validation_1-mae:378602
# [122]	validation_0-mae:538238	validation_1-mae:372681
# [123]	validation_0-mae:533224	validation_1-mae:366626
# [124]	validation_0-mae:528348	validation_1-mae:360352
# [125]	validation_0-mae:523516	validation_1-mae:354136
# [126]	validation_0-mae:518729	validation_1-mae:347979
# [127]	validation_0-mae:513986	validation_1-mae:343113
# [128]	validation_0-mae:509286	validation_1-mae:338797
# [129]	validation_0-mae:504630	validation_1-mae:334522
# [130]	validation_0-mae:499915	validation_1-mae:330532
# [131]	validation_0-mae:495344	validation_1-mae:326334
# [132]	validation_0-mae:490815	validation_1-mae:322176
# [133]	validation_0-mae:486734	validation_1-mae:318056
# [134]	validation_0-mae:482745	validation_1-mae:313975
# [135]	validation_0-mae:478688	validation_1-mae:310106
# [136]	validation_0-mae:474772	validation_1-mae:306099
# [137]	validation_0-mae:470914	validation_1-mae:302130
# [138]	validation_0-mae:467090	validation_1-mae:298198
# [139]	validation_0-mae:463280	validation_1-mae:294304
# [140]	validation_0-mae:459526	validation_1-mae:290445
# [141]	validation_0-mae:455806	validation_1-mae:286623
# [142]	validation_0-mae:451965	validation_1-mae:283110
# [143]	validation_0-mae:448197	validation_1-mae:279518
# [144]	validation_0-mae:444559	validation_1-mae:275798
# [145]	validation_0-mae:440974	validation_1-mae:272113
# [146]	validation_0-mae:437403	validation_1-mae:268463
# [147]	validation_0-mae:433884	validation_1-mae:264846
# [148]	validation_0-mae:430268	validation_1-mae:261471
# [149]	validation_0-mae:426794	validation_1-mae:257920
# [150]	validation_0-mae:423371	validation_1-mae:254403
# [151]	validation_0-mae:419870	validation_1-mae:251068
# [152]	validation_0-mae:416456	validation_1-mae:247916
# [153]	validation_0-mae:413019	validation_1-mae:244642
# [154]	validation_0-mae:409685	validation_1-mae:241545
# [155]	validation_0-mae:406311	validation_1-mae:238331
# [156]	validation_0-mae:403019	validation_1-mae:235288
# [157]	validation_0-mae:399706	validation_1-mae:232132
# [158]	validation_0-mae:396520	validation_1-mae:229326
# [159]	validation_0-mae:393267	validation_1-mae:226225
# [160]	validation_0-mae:390084	validation_1-mae:223003
# [161]	validation_0-mae:386981	validation_1-mae:220272
# [162]	validation_0-mae:383856	validation_1-mae:218131
# [163]	validation_0-mae:380800	validation_1-mae:216248
# [164]	validation_0-mae:377692	validation_1-mae:214470
# [165]	validation_0-mae:374670	validation_1-mae:212622
# [166]	validation_0-mae:371665	validation_1-mae:210470
# [167]	validation_0-mae:368701	validation_1-mae:208334
# [168]	validation_0-mae:365747	validation_1-mae:206214
# [169]	validation_0-mae:363041	validation_1-mae:203840
# [0]	validation_0-mae:1.18445e+06	validation_1-mae:688830
# [1]	validation_0-mae:1.17307e+06	validation_1-mae:677441
# [2]	validation_0-mae:1.16179e+06	validation_1-mae:666162
# [3]	validation_0-mae:1.15062e+06	validation_1-mae:654991
# [4]	validation_0-mae:1.13955e+06	validation_1-mae:643927
# [5]	validation_0-mae:1.12859e+06	validation_1-mae:632970
# [6]	validation_0-mae:1.11774e+06	validation_1-mae:622118
# [7]	validation_0-mae:1.107e+06	validation_1-mae:611371
# [8]	validation_0-mae:1.09635e+06	validation_1-mae:600726
# [9]	validation_0-mae:1.08581e+06	validation_1-mae:590184
# [10]	validation_0-mae:1.07537e+06	validation_1-mae:579744
# [11]	validation_0-mae:1.06503e+06	validation_1-mae:569404
# [12]	validation_0-mae:1.05479e+06	validation_1-mae:559163
# [13]	validation_0-mae:1.04465e+06	validation_1-mae:549021
# [14]	validation_0-mae:1.0346e+06	validation_1-mae:538976
# [15]	validation_0-mae:1.02465e+06	validation_1-mae:529028
# [16]	validation_0-mae:1.0148e+06	validation_1-mae:519176
# [17]	validation_0-mae:1.00504e+06	validation_1-mae:509418
# [18]	validation_0-mae:995591	validation_1-mae:500085
# [19]	validation_0-mae:986229	validation_1-mae:490840
# [20]	validation_0-mae:976955	validation_1-mae:481681
# [21]	validation_0-mae:967562	validation_1-mae:472287
# [22]	validation_0-mae:958463	validation_1-mae:463302
# [23]	validation_0-mae:949450	validation_1-mae:454401
# [24]	validation_0-mae:940522	validation_1-mae:445584
# [25]	validation_0-mae:931479	validation_1-mae:436541
# [26]	validation_0-mae:922719	validation_1-mae:427891
# [27]	validation_0-mae:914042	validation_1-mae:419322
# [28]	validation_0-mae:905253	validation_1-mae:410533
# [29]	validation_0-mae:896741	validation_1-mae:402127
# [30]	validation_0-mae:888308	validation_1-mae:393799
# [31]	validation_0-mae:879955	validation_1-mae:385550
# [32]	validation_0-mae:871494	validation_1-mae:377089
# [33]	validation_0-mae:863298	validation_1-mae:368996
# [34]	validation_0-mae:855180	validation_1-mae:360979
# [35]	validation_0-mae:847139	validation_1-mae:353038
# [36]	validation_0-mae:838993	validation_1-mae:344892
# [37]	validation_0-mae:831722	validation_1-mae:337101
# [38]	validation_0-mae:824573	validation_1-mae:329383
# [39]	validation_0-mae:817290	validation_1-mae:321467
# [40]	validation_0-mae:810276	validation_1-mae:313895
# [41]	validation_0-mae:803328	validation_1-mae:306394
# [42]	validation_0-mae:796445	validation_1-mae:298964
# [43]	validation_0-mae:789434	validation_1-mae:291343
# [44]	validation_0-mae:782682	validation_1-mae:284053
# [45]	validation_0-mae:775993	validation_1-mae:276832
# [46]	validation_0-mae:769367	validation_1-mae:269679
# [47]	validation_0-mae:762617	validation_1-mae:262343
# [48]	validation_0-mae:756116	validation_1-mae:255325
# [49]	validation_0-mae:749869	validation_1-mae:248373
# [50]	validation_0-mae:743879	validation_1-mae:241243
# [51]	validation_0-mae:738151	validation_1-mae:234423
# [52]	validation_0-mae:732476	validation_1-mae:227667
# [53]	validation_0-mae:726854	validation_1-mae:220975
# [54]	validation_0-mae:721088	validation_1-mae:214110
# [55]	validation_0-mae:715573	validation_1-mae:207545
# [56]	validation_0-mae:710109	validation_1-mae:201041
# [57]	validation_0-mae:704697	validation_1-mae:194598
# [58]	validation_0-mae:699147	validation_1-mae:187989
# [59]	validation_0-mae:693837	validation_1-mae:182153
# [60]	validation_0-mae:688577	validation_1-mae:178212
# [61]	validation_0-mae:683367	validation_1-mae:175832
# [62]	validation_0-mae:678023	validation_1-mae:173106
# [63]	validation_0-mae:672912	validation_1-mae:170772
# [64]	validation_0-mae:667848	validation_1-mae:168460
# [65]	validation_0-mae:662655	validation_1-mae:165810
# [66]	validation_0-mae:657687	validation_1-mae:163543
# [67]	validation_0-mae:652766	validation_1-mae:161296
# [68]	validation_0-mae:647892	validation_1-mae:159070
# [69]	validation_0-mae:642892	validation_1-mae:156519
# [70]	validation_0-mae:638110	validation_1-mae:154336
# [71]	validation_0-mae:633372	validation_1-mae:152173
# [72]	validation_0-mae:628679	validation_1-mae:150030
# [73]	validation_0-mae:623866	validation_1-mae:147574
# [74]	validation_0-mae:619262	validation_1-mae:145472
# [75]	validation_0-mae:614701	validation_1-mae:143390
# [76]	validation_0-mae:610023	validation_1-mae:141003
# [77]	validation_0-mae:605549	validation_1-mae:138961
# [78]	validation_0-mae:601086	validation_1-mae:136549
# [79]	validation_0-mae:596695	validation_1-mae:134544
# [80]	validation_0-mae:592346	validation_1-mae:132558
# [81]	validation_0-mae:587885	validation_1-mae:130282
# [82]	validation_0-mae:583618	validation_1-mae:128952
# [83]	validation_0-mae:579406	validation_1-mae:128185
# [84]	validation_0-mae:575219	validation_1-mae:127809
# [85]	validation_0-mae:570925	validation_1-mae:127079
# [86]	validation_0-mae:566817	validation_1-mae:126711
# [87]	validation_0-mae:562747	validation_1-mae:126346
# [88]	validation_0-mae:558716	validation_1-mae:125984
# [89]	validation_0-mae:554582	validation_1-mae:126290
# [90]	validation_0-mae:550627	validation_1-mae:127387
# [91]	validation_0-mae:546723	validation_1-mae:128098
# [92]	validation_0-mae:542843	validation_1-mae:129173
# [93]	validation_0-mae:538862	validation_1-mae:129850
# [94]	validation_0-mae:535054	validation_1-mae:130906
# [95]	validation_0-mae:531283	validation_1-mae:131952
# [96]	validation_0-mae:527560	validation_1-mae:132630
# [97]	validation_0-mae:523728	validation_1-mae:133281
# [98]	validation_0-mae:520062	validation_1-mae:134298
# [99]	validation_0-mae:516431	validation_1-mae:135305
# [100]	validation_0-mae:512707	validation_1-mae:135939
# [101]	validation_0-mae:509144	validation_1-mae:136928
# [102]	validation_0-mae:505615	validation_1-mae:137906
# [103]	validation_0-mae:502132	validation_1-mae:138540
# [104]	validation_0-mae:498546	validation_1-mae:139150
# [105]	validation_0-mae:495117	validation_1-mae:140102
# [106]	validation_0-mae:491719	validation_1-mae:141746
# [107]	validation_0-mae:488354	validation_1-mae:143914
# [108]	validation_0-mae:484902	validation_1-mae:145675
# [109]	validation_0-mae:481600	validation_1-mae:147803
# [110]	validation_0-mae:478329	validation_1-mae:149910
# [111]	validation_0-mae:475101	validation_1-mae:151673
# [112]	validation_0-mae:471777	validation_1-mae:153369
# [113]	validation_0-mae:468599	validation_1-mae:155418
# [114]	validation_0-mae:465450	validation_1-mae:157447
# [115]	validation_0-mae:462330	validation_1-mae:159456
# [116]	validation_0-mae:459131	validation_1-mae:161088
# [117]	validation_0-mae:456071	validation_1-mae:163060
# [118]	validation_0-mae:453050	validation_1-mae:164710
# [119]	validation_0-mae:450047	validation_1-mae:166644
# [120]	validation_0-mae:446966	validation_1-mae:168215
# [121]	validation_0-mae:444050	validation_1-mae:170236
# [122]	validation_0-mae:441160	validation_1-mae:172241
# [123]	validation_0-mae:438294	validation_1-mae:174231
# [124]	validation_0-mae:435435	validation_1-mae:175793
# [125]	validation_0-mae:432491	validation_1-mae:177295
# [126]	validation_0-mae:429703	validation_1-mae:179246
# [127]	validation_0-mae:426939	validation_1-mae:181182
# [128]	validation_0-mae:424200	validation_1-mae:183105
# [129]	validation_0-mae:421661	validation_1-mae:185013
# [130]	validation_0-mae:419113	validation_1-mae:186449
# [131]	validation_0-mae:416714	validation_1-mae:188333
# [132]	validation_0-mae:414336	validation_1-mae:190202
# [133]	validation_0-mae:411968	validation_1-mae:191642
# [134]	validation_0-mae:409631	validation_1-mae:193486
# [135]	validation_0-mae:407197	validation_1-mae:194859
# [136]	validation_0-mae:404902	validation_1-mae:196678
# [137]	validation_0-mae:402628	validation_1-mae:198484
# [138]	validation_0-mae:400373	validation_1-mae:200277
# [139]	validation_0-mae:398129	validation_1-mae:201641
# [140]	validation_0-mae:395914	validation_1-mae:203409
# [141]	validation_0-mae:393608	validation_1-mae:204710
# [142]	validation_0-mae:391120	validation_1-mae:206481
# [143]	validation_0-mae:388653	validation_1-mae:208236
# [144]	validation_0-mae:386207	validation_1-mae:210176
# [145]	validation_0-mae:383816	validation_1-mae:212326
# [146]	validation_0-mae:381529	validation_1-mae:214458
# [147]	validation_0-mae:379262	validation_1-mae:216570
# [148]	validation_0-mae:377014	validation_1-mae:218664
# [149]	validation_0-mae:374786	validation_1-mae:220740
# [150]	validation_0-mae:372576	validation_1-mae:222797
# [151]	validation_0-mae:370385	validation_1-mae:224836
# [152]	validation_0-mae:368212	validation_1-mae:226858
# [153]	validation_0-mae:366058	validation_1-mae:228862
# [154]	validation_0-mae:363922	validation_1-mae:231116
# [155]	validation_0-mae:361805	validation_1-mae:233914
# [156]	validation_0-mae:359705	validation_1-mae:236687
# [157]	validation_0-mae:357667	validation_1-mae:239964
# [158]	validation_0-mae:355647	validation_1-mae:243213
# [159]	validation_0-mae:353598	validation_1-mae:245915
# [160]	validation_0-mae:351610	validation_1-mae:249116
# [161]	validation_0-mae:349639	validation_1-mae:252290
# [162]	validation_0-mae:347786	validation_1-mae:254923
# [163]	validation_0-mae:345994	validation_1-mae:258049
# [164]	validation_0-mae:344243	validation_1-mae:260636
# [165]	validation_0-mae:342420	validation_1-mae:263676
# [166]	validation_0-mae:340672	validation_1-mae:266730
# [167]	validation_0-mae:338963	validation_1-mae:269251
# [168]	validation_0-mae:337185	validation_1-mae:272221
# [169]	validation_0-mae:335504	validation_1-mae:274699
# XGBRegressor(learning_rate=0.01, n_estimators=170, objective='reg:squarederror')

# %%
predictions_calcio = estimator_calcio.predict(x_calcio_to_test)
predictions_pesca = estimator_pesca.predict(x_pesca_to_test)
predictions_casual = estimator_casual.predict(x_casual_to_test)

#ds_calcio_annuale = ds_calcio_annuale.reset_index().drop('index', axis=1)  #non posso usarli perchè me li aggiunge all'inizio del dataset
#ds_calcio_annuale['predictions'] = pd.Series(predictions)

#plt.rcParams.update({'figure.figsize': (17, 3), 'figure.dpi':300})
#fig, ax = plt.subplots()
#sns.lineplot(data=ds_calcio_annuale, x= "year", y='revenue')
#sns.lineplot(data=ds_calcio_annuale, x='year', y='predictions', palette= "red")
#plt.grid(linestyle='-', linewidth=0.3)
#ax.tick_params(axis='x', rotation=90)

# %%
calcio_evalutation_ds = ds_calcio[(len(ds_calcio)-porzione_test):]   
calcio_evalutation_ds = calcio_evalutation_ds.reset_index().drop('index', axis=1)
calcio_evalutation_ds['predictions'] = pd.Series(predictions_calcio)
calcio_evalutation_ds
# Out:
#    Unnamed: 0       year     revenue  totale_periodo_prec   predictions
# 0          26 2020-09-30  2254753.87            455953.91  1.146918e+06
# 1          27 2020-12-31  1170900.69           2254753.87  9.984099e+05
# 2          28 2021-03-31   509403.89           1170900.69  7.569002e+05
# 3          29 2021-06-30   589663.53            509403.89  1.146918e+06
# 4          30 2021-09-30  1257807.31            589663.53  1.146918e+06
# 5          31 2021-12-31  1350740.40           1257807.31  7.569002e+05
# 6          32 2022-03-31   781360.53           1350740.40  7.569002e+05

# %%
pesca_evalutation_ds = ds_pesca[(len(ds_pesca)-porzione_test):]  
pesca_evalutation_ds = pesca_evalutation_ds.reset_index().drop('index', axis=1)
pesca_evalutation_ds['predictions'] = pd.Series(predictions_pesca)
pesca_evalutation_ds
# Out:
#    Unnamed: 0       year     revenue  totale_periodo_prec  predictions
# 0          26 2020-09-30  1727871.52           3000092.88  1666113.000
# 1          27 2020-12-31  1881887.80           1727871.52  1639987.625
# 2          28 2021-03-31  2258617.01           1881887.80  1651229.375
# 3          29 2021-06-30  1923040.08           2258617.01  1666113.000
# 4          30 2021-09-30  1620445.53           1923040.08  1651229.375
# 5          31 2021-12-31  1704044.85           1620445.53  1667159.625
# 6          32 2022-03-31  1448752.71           1704044.85  1639987.625

# %%
casual_evalutation_ds = ds_casual[(len(ds_casual)-porzione_test):]  
casual_evalutation_ds = casual_evalutation_ds.reset_index().drop('index', axis=1)
casual_evalutation_ds['predictions'] = pd.Series(predictions_casual)
casual_evalutation_ds
# Out:
#    Unnamed: 0       year    revenue  totale_periodo_prec   predictions
# 0          26 2020-09-30  674152.55           1731979.27  1.021223e+06
# 1          27 2020-12-31  789520.75            674152.55  1.030637e+06
# 2          28 2021-03-31  985770.75            789520.75  1.030637e+06
# 3          29 2021-06-30  709238.48            985770.75  9.680299e+05
# 4          30 2021-09-30  543018.66            709238.48  1.030637e+06
# 5          31 2021-12-31  664677.44            543018.66  7.134047e+05
# 6          32 2022-03-31  535933.31            664677.44  1.030637e+06

# %%
#TROVARE UN VALUTATORE DELLE PERFORMANCE DI FITTING ANALOGO PER L'XGBOOST
#print('Did the model fit?', pd.Series(predictions_calcio).is_fitted) 
#print('AIC', pd.Series(predictions).aic) 
#print(pesca_evalutation_ds.summary())

# %%
plt.rcParams.update({'figure.figsize': (17, 3), 'figure.dpi':300})
fig, ax = plt.subplots()
sns.lineplot(data=ds_calcio, x= "year", y='revenue', label= "Corretti" )     #_evalutation
sns.lineplot(data=calcio_evalutation_ds, x='year', y='predictions', palette= "red",  label= "Predetti")

#x = calcio_evalutation_ds['year']  
#y = calcio_evalutation_ds['predictions']
#for i,j in zip(x,y):
#  plt.annotate(str(j),xy=(i,j))
#
#y1 = calcio_evalutation_ds['revenue']
#for i,j in zip(x,y1):
#  plt.annotate(str(j),xy=(i,j))
#  calcio_evalutation_ds

plt.title("Predizione vendite Calcio trimestrale")

plt.grid(linestyle='-', linewidth=0.3)
ax.tick_params(axis='x', rotation=90)

# %%
plt.rcParams.update({'figure.figsize': (17, 3), 'figure.dpi':300})
fig, ax = plt.subplots()
sns.lineplot(data=ds_pesca, x= "year", y='revenue', label= "Corretti")     
sns.lineplot(data=pesca_evalutation_ds, x='year', y='predictions', palette= "red", label= "Predetti") 

#x = pesca_evalutation_ds['year']  
#y = pesca_evalutation_ds['predictions']
#for i,j in zip(x,y):
#  plt.annotate(str(j),xy=(i,j))
#
#y1 = pesca_evalutation_ds['revenue']
#for i,j in zip(x,y1):
#  plt.annotate(str(j),xy=(i,j))
#  pesca_evalutation_ds

plt.title("Predizione vendite Pesca trimestrale")

plt.grid(linestyle='-', linewidth=0.3)
ax.tick_params(axis='x', rotation=90)

# %%
plt.rcParams.update({'figure.figsize': (17, 3), 'figure.dpi':300})
fig, ax = plt.subplots()
sns.lineplot(data=ds_casual, x= "year", y='revenue', label= "Corretti")     
sns.lineplot(data=casual_evalutation_ds, x='year', y='predictions', palette= "red", label= "Predetti") 

#x = casual_evalutation_ds['year']  
#y = casual_evalutation_ds['predictions']
#for i,j in zip(x,y):
#  plt.annotate(str(j),xy=(i,j))
#
#y1 = casual_evalutation_ds['revenue']
#for i,j in zip(x,y1):
#  plt.annotate(str(j),xy=(i,j))
#  casual_evalutation_ds

plt.title("Predizione vendite Casual trimestrale")

plt.grid(linestyle='-', linewidth=0.3)
ax.tick_params(axis='x', rotation=90)

# %%
calcio_evalutation_ds
# Out:
#    Unnamed: 0       year     revenue  totale_periodo_prec   predictions
# 0          26 2020-09-30  2254753.87            455953.91  1.146918e+06
# 1          27 2020-12-31  1170900.69           2254753.87  9.984099e+05
# 2          28 2021-03-31   509403.89           1170900.69  7.569002e+05
# 3          29 2021-06-30   589663.53            509403.89  1.146918e+06
# 4          30 2021-09-30  1257807.31            589663.53  1.146918e+06
# 5          31 2021-12-31  1350740.40           1257807.31  7.569002e+05
# 6          32 2022-03-31   781360.53           1350740.40  7.569002e+05

# %%
pesca_evalutation_ds
# Out:
#    Unnamed: 0       year     revenue  totale_periodo_prec  predictions
# 0          26 2020-09-30  1727871.52           3000092.88  1666113.000
# 1          27 2020-12-31  1881887.80           1727871.52  1639987.625
# 2          28 2021-03-31  2258617.01           1881887.80  1651229.375
# 3          29 2021-06-30  1923040.08           2258617.01  1666113.000
# 4          30 2021-09-30  1620445.53           1923040.08  1651229.375
# 5          31 2021-12-31  1704044.85           1620445.53  1667159.625
# 6          32 2022-03-31  1448752.71           1704044.85  1639987.625

# %%
casual_evalutation_ds
# Out:
#    Unnamed: 0       year    revenue  totale_periodo_prec   predictions
# 0          26 2020-09-30  674152.55           1731979.27  1.021223e+06
# 1          27 2020-12-31  789520.75            674152.55  1.030637e+06
# 2          28 2021-03-31  985770.75            789520.75  1.030637e+06
# 3          29 2021-06-30  709238.48            985770.75  9.680299e+05
# 4          30 2021-09-30  543018.66            709238.48  1.030637e+06
# 5          31 2021-12-31  664677.44            543018.66  7.134047e+05
# 6          32 2022-03-31  535933.31            664677.44  1.030637e+06

# %%
print('Calcio XgBoost Mean Absolute Error (MAE): ', np.mean(np.abs(calcio_evalutation_ds["revenue"] - calcio_evalutation_ds["predictions"])))
# Out:
# Calcio XgBoost Mean Absolute Error (MAE):  402038.1882142857

# %%
print('Pesca XgBoost Mean Absolute Error (MAE): ', np.mean(np.abs(pesca_evalutation_ds["revenue"] - pesca_evalutation_ds["predictions"])))
# Out:
# Pesca XgBoost Mean Absolute Error (MAE):  203839.62785714286

# %%
print('Casual XgBoost Mean Absolute Error (MAE): ', np.mean(np.abs(casual_evalutation_ds["revenue"] - casual_evalutation_ds["predictions"])))
# Out:
# Casual XgBoost Mean Absolute Error (MAE):  274699.1782142857

# %%
def mean_absolute_percentage_error(y_true, y_pred): 
    y_true, y_pred = np.array(y_true), np.array(y_pred)
    return np.mean(np.abs((y_true - y_pred) / y_true)) * 100

# %%
print('Calcio XgBoost Mean Absolute Percentage Error (MAPE): ', mean_absolute_percentage_error(calcio_evalutation_ds["revenue"], calcio_evalutation_ds["predictions"]))
# Out:
# Calcio XgBoost Mean Absolute Percentage Error (MAPE):  37.55209786845043

# %%
print('Pesca XgBoost Mean Absolute Percentage Error (MAPE): ', mean_absolute_percentage_error(pesca_evalutation_ds["revenue"], pesca_evalutation_ds["predictions"]))
# Out:
# Pesca XgBoost Mean Absolute Percentage Error (MAPE):  10.563587158567701

# %%
print('Casual XgBoost Mean Absolute Percentage Error (MAPE): ', mean_absolute_percentage_error(casual_evalutation_ds["revenue"], casual_evalutation_ds["predictions"]))
# Out:
# Casual XgBoost Mean Absolute Percentage Error (MAPE):  44.64254060958241

# %% [markdown]
# (170 estimator valore intermedio per tutti e tre i dataset con shift di 1 mese)
#
# (Calcio migliore intorno ai 200)
# (Pesca migliore intorno ai 180)
# (Casual migliore intorno ai 90)
#
#
#
#
# Con shift +1 trimestre
#
#
# * Calcio XgBoost Mean Absolute Error (MAE):  402038.1882142857
# * Pesca XgBoost Mean Absolute Error (MAE):  203839.62785714286
# * Casual XgBoost Mean Absolute Error (MAE):  274699.1782142857
#
#
# * Calcio XgBoost Mean Absolute Percentage Error (MAPE):  37.55 %
# * Pesca XgBoost Mean Absolute Percentage Error (MAPE):  10.56 %
# * Casual XgBoost Mean Absolute Percentage Error (MAPE):  44.64 %
#
#
#
#
# Con shift +4 trimestri
#
#
# * Calcio XgBoost Mean Absolute Error (MAE):  443181.4224999999
# * Pesca XgBoost Mean Absolute Error (MAE):  245233.77785714282
# * Casual XgBoost Mean Absolute Error (MAE):  261661.8442857143
#
#
# * Calcio XgBoost Mean Absolute Percentage Error (MAPE):  37.31 %
# * Pesca XgBoost Mean Absolute Percentage Error (MAPE):  12.79 %
# * Casual XgBoost Mean Absolute Percentage Error (MAPE):  40.15 %
